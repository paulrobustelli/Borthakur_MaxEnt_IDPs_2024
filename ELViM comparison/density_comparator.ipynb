# %%
from density_comparator import lsdir, DensityComparator, symbols, combinations, dJS, dKL
import numpy as np
from pandas import DataFrame
from IPython.display import display

# %%
root = "/home/t/r1r2/kaush"
protein_paths = lsdir("/home/t/r1r2/kaush", exclude=[".py", "elvim", "png", "ELViM", "X", "weights", "density"])[::-1]
proteins = [f"{symbols('alpha')}-Synuclein", "PaaA2", "ACTR", "drkN-SH3", f"A{symbols('beta')}-40"]
force_feilds = ["a99SBdisp", "Charmm36m", "c22star-TIP3P"]
ff_pairs = ["/".join(i.tolist()) for i in combinations(force_feilds)]
weight_files = [[lsdir(f"{path}/{ff}", keyword="weight") for ff in force_feilds] for path in protein_paths]
elvim_files = [lsdir(f"{path}/elvim", keyword="cat", exclude="npy")[0] for path in protein_paths]
weights = np.stack([np.stack([np.loadtxt(lsdir(f"{path}/{ff}", keyword="weight")[0])[1:][::2] for ff in force_feilds]) for path in protein_paths])
elvim = np.stack([np.stack([i[1:] for i in np.array_split(np.loadtxt(lsdir(f"{path}/elvim", keyword="cat", exclude="npy")[0]), 3)]) for path in protein_paths])
# Out:
# /home/t/r1r2/kaush/density_comparision/density_comparator.py:396: UserWarning: Not all strings contain a number, returning unsorted input list to avoid throwing an error. If you want to only consider strings that contain a digit, set indexed to True
#   warnings.warn("Not all strings contain a number, returning unsorted input list to avoid throwing an error. "

# %%
metrics = (None, dJS, dKL)
metric_names = "Overlap Integral,JS,KL".split(",")
for index in range(5):
    
    dens = DensityComparator(data=[i for i in elvim[index]],
                         weights=[i for i in weights[index]])
    dens.estimate_hist();dens.estimate_hist(weight=True)
    dens.estimate_kde(); dens.estimate_kde(weight=True)
    
    dens.plot_kde(dscr=proteins[index], dscrs=force_feilds)
    dens.plot_kde(dscr=proteins[index], dscrs=force_feilds, weight=True)
    
    for metric, metric_name in zip(metrics, metric_names):
        
        print(f"Similarity Metrics and densities used to compute them for {proteins[index]}")

        df = DataFrame(data=np.stack([dens.compare("kdes", metric=metric), dens.compare("kdes", weight=True, metric=metric)]), 
                           index="Unbiased,Reweighted".split(","),
                           columns=ff_pairs)
        
        df.columns.name = f"{proteins[index]} : {metric_name}"
    
        display(df)
# Out:
# Similarity Metrics and densities used to compute them for α-Synuclein
# α-Synuclein : Overlap Integral  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                                   0.018977                 0.004489
# Reweighted                                 0.099801                 0.034920
#
# α-Synuclein : Overlap Integral  Charmm36m/c22star-TIP3P
# Unbiased                                       0.000255
# Reweighted                                     0.009525
# Similarity Metrics and densities used to compute them for α-Synuclein
# α-Synuclein : JS  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                     0.628451                 0.674026
# Reweighted                   0.541249                 0.626015
#
# α-Synuclein : JS  Charmm36m/c22star-TIP3P
# Unbiased                         0.688369
# Reweighted                       0.652625
# Similarity Metrics and densities used to compute them for α-Synuclein
# α-Synuclein : KL  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                     9.628288                87.771001
# Reweighted                   5.331013                24.669814
#
# α-Synuclein : KL  Charmm36m/c22star-TIP3P
# Unbiased                        60.853551
# Reweighted                      25.242203
# Similarity Metrics and densities used to compute them for PaaA2
# PaaA2 : Overlap Integral  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                             0.015364                 0.017298
# Reweighted                           0.046237                 0.123126
#
# PaaA2 : Overlap Integral  Charmm36m/c22star-TIP3P
# Unbiased                                  0.00641
# Reweighted                                0.21164
# Similarity Metrics and densities used to compute them for PaaA2
# PaaA2 : JS  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased               0.643698                 0.641228
# Reweighted             0.596492                 0.517145
#
# PaaA2 : JS  Charmm36m/c22star-TIP3P
# Unbiased                   0.663126
# Reweighted                 0.472597
# Similarity Metrics and densities used to compute them for PaaA2
# PaaA2 : KL  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased              16.107241                 9.864171
# Reweighted             7.469361                 3.720845
#
# PaaA2 : KL  Charmm36m/c22star-TIP3P
# Unbiased                  44.387765
# Reweighted                 6.476405
# Similarity Metrics and densities used to compute them for ACTR
# ACTR : Overlap Integral  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                            0.728358                 0.127655
# Reweighted                          0.737978                 0.613062
#
# ACTR : Overlap Integral  Charmm36m/c22star-TIP3P
# Unbiased                                0.273383
# Reweighted                              0.759765
# Similarity Metrics and densities used to compute them for ACTR
# ACTR : JS   a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased               0.117719                 0.442649
# Reweighted             0.085222                 0.155842
#
# ACTR : JS   Charmm36m/c22star-TIP3P
# Unbiased                   0.328164
# Reweighted                 0.080815
# Similarity Metrics and densities used to compute them for ACTR
# ACTR : KL   a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased               0.448860                 2.468684
# Reweighted             0.308036                 0.629002
#
# ACTR : KL   Charmm36m/c22star-TIP3P
# Unbiased                   1.636146
# Reweighted                 0.324609
# Similarity Metrics and densities used to compute them for drkN-SH3
# drkN-SH3 : Overlap Integral  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                                0.036986                 0.184276
# Reweighted                              0.401198                 0.614887
#
# drkN-SH3 : Overlap Integral  Charmm36m/c22star-TIP3P
# Unbiased                                    0.129108
# Reweighted                                  0.561609
# Similarity Metrics and densities used to compute them for drkN-SH3
# drkN-SH3 : JS  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                  0.577874                 0.415343
# Reweighted                0.301030                 0.177107
#
# drkN-SH3 : JS  Charmm36m/c22star-TIP3P
# Unbiased                      0.420768
# Reweighted                    0.182859
# Similarity Metrics and densities used to compute them for drkN-SH3
# drkN-SH3 : KL  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                  3.792275                 2.082372
# Reweighted                1.354258                 0.795273
#
# drkN-SH3 : KL  Charmm36m/c22star-TIP3P
# Unbiased                      3.596797
# Reweighted                    1.083797
# Similarity Metrics and densities used to compute them for Aβ-40
# Aβ-40 : Overlap Integral  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased                             0.645274                 0.383826
# Reweighted                           0.842567                 0.762458
#
# Aβ-40 : Overlap Integral  Charmm36m/c22star-TIP3P
# Unbiased                                 0.329806
# Reweighted                               0.578038
# Similarity Metrics and densities used to compute them for Aβ-40
# Aβ-40 : JS  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased               0.118728                 0.266023
# Reweighted             0.053142                 0.112050
#
# Aβ-40 : JS  Charmm36m/c22star-TIP3P
# Unbiased                   0.287887
# Reweighted                 0.165803
# Similarity Metrics and densities used to compute them for Aβ-40
# Aβ-40 : KL  a99SBdisp/Charmm36m  a99SBdisp/c22star-TIP3P  \
# Unbiased               0.712662                 1.553778
# Reweighted             0.239352                 0.492309
#
# Aβ-40 : KL  Charmm36m/c22star-TIP3P
# Unbiased                   1.472385
# Reweighted                 0.789030
